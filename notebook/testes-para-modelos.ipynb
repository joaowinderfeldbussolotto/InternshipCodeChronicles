# %% [markdown]
# # trabalhando com alguns testes - /tmp/ notebook

# %%
import pandas as pd
import os

# %%
df = pd.read_csv(os.getcwd() + '/datasets/Hotel Reservations.csv')
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %%
def mapLabel(value, delimiters = [85, 115]):
  if value <= delimiters[0]:
    return 1
  elif value > delimiters[0] and value < delimiters[1]:
    return 2
  return 3

def assignLabelAvgPrice(df):
  df['label_avg_price_per_room'] = df['avg_price_per_room'].apply(mapLabel)

# %%
assignLabelAvgPrice(df)
df.drop(columns = 'avg_price_per_room', inplace = True)

# %%
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %% [markdown]
# # salvando dataset df para arquivo

# %%
os.makedirs('./datasets/datasets-para-autopilot', exist_ok=True)
mod_dataset_name = 'datasets/datasets-para-autopilot/mod-hotel_res.csv'
df.to_csv('./{}'.format(mod_dataset_name), index=False)

# %% [markdown]
# # enviando dados para o s3 : path "atomic-sp5-autopilot-teste"-> dataset/mod-dataset/

# %%
import boto3
from sagemaker.s3 import S3Uploader
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
session = boto3.Session()
session.region_name
# Out:
# 'us-east-1'

# %%
bucket = 'atomic-sp5-autopilot-teste'
subp   = 'dataset/mod-dataset'
path_onbucket   = "s3://{}/{}".format(bucket, subp)
print(path)
# Out:
# s3://atomic-sp5-autopilot-teste/dataset/mod-dataset

# %%
s3_mod_dataset = S3Uploader.upload(mod_dataset_name, path)
print(s3_mod_dataset)
# Out:
# s3://atomic-sp5-autopilot-teste/dataset/mod-dataset/mod-hotel_res.csv

# %% [markdown]
# # criando versao reduzida do dataset

# %%
mod_dataset_name_red = mod_dataset_name[:-4] + '-red' + mod_dataset_name[-4:]
df.head(500).to_csv(mod_dataset_name_red, index=False)

# %% [markdown]
# ## enviando dataset para s3

# %%
s3_mod_dataset_red = S3Uploader.upload(mod_dataset_name_red, path)
print(s3_mod_dataset_red)
# Out:
# s3://atomic-sp5-autopilot-teste/dataset/mod-dataset/mod-hotel_res-red.csv
